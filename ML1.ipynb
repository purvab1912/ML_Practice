# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
#all rows without first column that is unnamed
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as p

# %%
p.scatter(df['cgpa'], df['iq'], c=df['placement'])

# %%
X = df.iloc[:, :2]
Y = df.iloc[:, -1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=0.1)
#spliting the data for train and test from the data set 10 percent of X and Y will go to test that is 0.1 size and 90% will go for train.)

# %%
X_train
# Out:
#     cgpa     iq
# 24   4.7  121.0
# 62   6.0  102.0
# 5    7.1   48.0
# 1    5.9  106.0
# 3    7.4  132.0
# ..   ...    ...
# 66   6.9   96.0
# 2    5.3  121.0
# 23   4.7   87.0
# 31   3.9  109.0
# 42   7.6   89.0
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 39   4.6  146.0
# 33   6.0  149.0
# 88   4.4  149.0
# 60   6.9  139.0
# 49   5.4  135.0
# 7    5.0   63.0
# 48   6.6  138.0
# 9    5.1   66.0
# 54   6.4  141.0
# 57   6.5  130.0

# %%
Y_train
# Out:
# 24    0
# 62    0
# 5     1
# 1     0
# 3     1
#      ..
# 66    1
# 2     0
# 23    0
# 31    0
# 42    1
# Name: placement, Length: 90, dtype: int64

# %%
Y_test
# Out:
# 39    0
# 33    0
# 88    0
# 60    1
# 49    0
# 7     0
# 48    1
# 9     0
# 54    1
# 57    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler() 
#creating a object of standardscaler

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.14146925, -0.05803813],
#        [-0.02106739, -0.52617588],
#        [ 0.92696496, -1.85667265],
#        [-0.10725214, -0.42762056],
#        [ 1.18551924,  0.21298899],
#        [ 0.23748689, -0.50153705],
#        [-0.27962166,  0.21298899],
#        [ 0.58222593,  1.44493044],
#        [-0.6243607 , -0.23050993],
#        [ 1.35788876,  0.11443367],
#        [-1.40002353, -2.00450562],
#        [ 1.96118207,  1.09998683],
#        [-1.48620829,  1.88842936],
#        [-0.96909973,  0.26226665],
#        [-0.53817594, -0.40298174],
#        [-0.53817594,  0.38546079],
#        [-0.96909973,  0.68112674],
#        [-0.27962166,  1.12462566],
#        [ 0.66841069, -0.82184183],
#        [-1.05528449, -0.27978759],
#        [-2.17568636,  2.70151071],
#        [ 1.53025827, -0.23050993],
#        [ 0.8407802 ,  1.27245863],
#        [-0.96909973, -0.08267696],
#        [ 1.09933448, -0.92039714],
#        [ 0.49604117, -0.08267696],
#        [ 0.40985641, -2.12769976],
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.22765401,  0.55793259],
#        [-0.02106739,  0.63184908],
#        [-1.40002353,  0.63184908],
#        [ 0.75459544,  0.38546079],
#        [-0.53817594,  0.28690548],
#        [-0.88291497, -1.48709021],
#        [ 0.49604117,  0.36082196],
#        [-0.79673022, -1.41317372],
#        [ 0.32367165,  0.43473845],
#        [ 0.40985641,  0.16371133]])

# %%
from sklearn.linear_model import LinearRegression

# %%
clf = LinearRegression()

# %%
#model training
clf.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
p_pred = clf.predict(X_test)

# %%
Y_test
# Out:
# 39    0
# 33    0
# 88    0
# 60    1
# 49    0
# 7     0
# 48    1
# 9     0
# 54    1
# 57    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,p_pred_binary)
# Out:
# 1.0

# %%
import mlxtend
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, Y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
